# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmancovidales/Aplicaciones-en-finanzas/blob/main/prepro_siniestros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerias generales
import pandas as pd
import numpy as np
import re
# Librerias y visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta del archivo en Google Drive
file_path = '/content/drive/MyDrive/analitica3/Financiera/DB_Siniestros.txt'

# Carga el archivo TXT en un DataFrame de Pandas
df = pd.read_csv(file_path, delimiter=',')

# %%
df
# Out:
#          Mes_Pago  Asegurado_Id              Reclamacion Diagnostico_Codigo  \
# 0          201803       4834968  EXAMENES DE DIAGNOSTICO               Z011
# 1          201909      14915125  EXAMENES DE DIAGNOSTICO                  9
# 2          201807      42959949  EXAMENES DE DIAGNOSTICO                  9
# 3          201803      30540131         CONSULTA EXTERNA                  9
# 4          201905      21442420      LABORATORIO CLINICO                  9
# ...           ...           ...                      ...                ...
# 3308475    201912       6197783  EXAMENES DE DIAGNOSTICO                  9
# 3308476    201905       1001139         CONSULTA EXTERNA                  9
# 3308477    201803      21888100    CONSULTA DE URGENCIAS                  9
# 3308478    201805      56483856    CONSULTA DE URGENCIAS                  9
# 3308479    201902      10095316         CONSULTA EXTERNA                  9
#
# ...
