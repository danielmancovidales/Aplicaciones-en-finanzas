# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmancovidales/Aplicaciones-en-finanzas/blob/main/prepro_expuestos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerias generales
import pandas as pd
import numpy as np
import re
# Librerias y visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta del archivo en Google Drive
file_path = '/content/drive/MyDrive/analitica3/Financiera/BD_Expuestos.txt'

# Carga el archivo TXT en un DataFrame de Pandas
df = pd.read_csv(file_path, delimiter='\t', encoding='latin1')

# %%
df
# Out:
#         Asegurado_Id  Poliza_Asegurado_Id FECHA_INICIO FECHA_CANCELACION  \
# 0           16286173            125696117   2018/01/01        2018/04/10
# 1           11885152            141320760   2018/01/01               NaN
# 2             763957            162532851   2018/01/01               NaN
# 3           29082204            154620473   2018/01/01        2018/04/19
# 4            4567640             93633862   2018/01/01               NaN
# ...              ...                  ...          ...               ...
# 300895      28476983             53646742   2018/01/01               NaN
# 300896       8479396             89963102   2018/01/01        2018/03/08
# 300897       6598270            165960557   2018/02/28               NaN
# 300898       1000907            105811540   2018/01/01               NaN
# 300899      34905586            161843515   2018/01/01               NaN
#
#          FECHA_FIN
# 0       2018/04/10
# 1       2019/12/31
# 2       2019/12/31
# ...
