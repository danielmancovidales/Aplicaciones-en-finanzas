# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmancovidales/Aplicaciones-en-finanzas/blob/main/prepro_sociodemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerias generales
import pandas as pd
import numpy as np
import re
# Librerias y visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta del archivo en Google Drive
file_path = '/content/drive/MyDrive/analitica3/Financiera/BD_Sociodemograficas.txt'

# Carga el archivo TXT en un DataFrame de Pandas
df = pd.read_csv(file_path, delimiter='\t', encoding='latin1')

# %%
df
# Out:
#         Asegurado_Id  Mujer FechaNacimiento    Ciudad  CANCER  EPOC  DIABETES  \
# 0           18686469      1      17/01/1984    Bogota       0     0         0
# 1           16087775      0      12/03/1984  Medellin       0     0         0
# 2           35757761      1      19/12/1993    Bogota       0     0         0
# 3           48691460      0      14/11/2000    Bogota       0     0         0
# 4           36074099      1       6/08/2015      Cali       0     0         0
# ...              ...    ...             ...       ...     ...   ...       ...
# 267307      21676160      1      21/01/1988    Bogota       0     0         0
# 267308       4782725      1      23/01/1975      Cali       0     0         0
# 267309      10100593      1       4/07/1975  Medellin       0     1         0
# 267310      34178573      1      15/10/1978      Cali       0     0         0
# 267311       4419287      1       6/10/1950  Medellin       0     0         0
#
# ...
